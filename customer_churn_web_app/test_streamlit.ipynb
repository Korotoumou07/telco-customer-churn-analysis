# %%
import joblib

model = joblib.load(
    "model/final_churn_model.pkl"
)

print("Model loaded successfully")
# Out:
# Model loaded successfully

# %%
pip install streamlit==1.35.0
# Out:
# Requirement already satisfied: streamlit==1.35.0 in c:\users\kotic\anaconda3\lib\site-packages (1.35.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\kotic\anaconda3\lib\site-packages (from streamlit==1.35.0) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\kotic\anaconda3\lib\site-packages (from streamlit==1.35.0) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\kotic\anaconda3\lib\site-packages (from streamlit==1.35.0) (4.2.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\kotic\anaconda3\lib\site-packages (from streamlit==1.35.0) (8.1.7)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\kotic\anaconda3\lib\site-packages (from streamlit==1.35.0) (1.26.4)
# Requirement already satisfied: packaging<25,>=16.8 in c:\users\kotic\anaconda3\lib\site-packages (from streamlit==1.35.0) (24.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\kotic\anaconda3\lib\site-packages (from streamlit==1.35.0) (2.1.4)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\kotic\anaconda3\lib\site-packages (from streamlit==1.35.0) (10.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\kotic\anaconda3\lib\site-packages (from streamlit==1.35.0) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\kotic\anaconda3\lib\site-packages (from streamlit==1.35.0) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\kotic\anaconda3\lib\site-packages (from streamlit==1.35.0) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\kotic\anaconda3\lib\site-packages (from streamlit==1.35.0) (13.3.5)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\kotic\anaconda3\lib\site-packages (from streamlit==1.35.0) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\kotic\anaconda3\lib\site-packages (from streamlit==1.35.0) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\kotic\anaconda3\lib\site-packages (from streamlit==1.35.0) (4.9.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\kotic\anaconda3\lib\site-packages (from streamlit==1.35.0) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\kotic\anaconda3\lib\site-packages (from streamlit==1.35.0) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\kotic\anaconda3\lib\site-packages (from streamlit==1.35.0) (6.3.3)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\kotic\anaconda3\lib\site-packages (from streamlit==1.35.0) (2.1.6)
# Requirement already satisfied: jinja2 in c:\users\kotic\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit==1.35.0) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\kotic\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit==1.35.0) (4.19.2)
# Requirement already satisfied: toolz in c:\users\kotic\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit==1.35.0) (0.12.0)
# Requirement already satisfied: colorama in c:\users\kotic\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit==1.35.0) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\kotic\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.35.0) (4.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kotic\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit==1.35.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kotic\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit==1.35.0) (2026.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\kotic\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit==1.35.0) (2026.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kotic\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit==1.35.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kotic\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit==1.35.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kotic\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit==1.35.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kotic\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit==1.35.0) (2026.1.4)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\kotic\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit==1.35.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kotic\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit==1.35.0) (2.15.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\kotic\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.35.0) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kotic\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit==1.35.0) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\kotic\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.35.0) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\kotic\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.35.0) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\kotic\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.35.0) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\kotic\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.35.0) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kotic\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.14.0->streamlit==1.35.0) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\kotic\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit==1.35.0) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !streamlit run app.py
